# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('all_tickets_processed_improved_v3.csv')
df.head
# Out:
# <bound method NDFrame.head of                                                 Document    Topic_group
# 0      connection with icon icon dear please setup ic...       Hardware
# 1      work experience user work experience user hi w...         Access
# 2      requesting for meeting requesting meeting hi p...       Hardware
# 3      reset passwords for external accounts re expir...         Access
# 4      mail verification warning hi has got attached ...  Miscellaneous
# ...                                                  ...            ...
# 47832  git space for a project issues with adding use...         Access
# 47833  error sent july error hi guys can you help out...  Miscellaneous
# 47834  connection issues sent tuesday july connection...       Hardware
# 47835  error cube reports sent tuesday july error hel...     HR Support
# 47836  running out on extensions hello please be advi...       Hardware
#
# [47837 rows x 2 columns]>

# %%
df.columns
# Out:
# Index(['Document', 'Topic_group'], dtype='object')

# %%
df.Topic_group.value_counts()
# Out:
# Hardware                 13617
# HR Support               10915
# Access                    7125
# Miscellaneous             7060
# Storage                   2777
# Purchase                  2464
# Internal Project          2119
# Administrative rights     1760
# Name: Topic_group, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Document'])

# %%
X
# Out:
# <47837x12325 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1429908 stored elements in Compressed Sparse Row format>

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['ab', 'abandon', 'abandoned', ..., 'zoom', 'zooming', 'zori'],
#       dtype=object)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=50)
reduced_data = pca.fit_transform(X.toarray())

# %%
reduced_data
# Out:
# array([[-0.00916055,  0.00106133, -0.01364971, ...,  0.00997621,
#          0.04553043,  0.01843808],
#        [-0.01848961,  0.02134666, -0.05115649, ..., -0.01731179,
#         -0.02316814,  0.00621243],
#        [-0.02452673, -0.01734513, -0.02659567, ...,  0.06220629,
#         -0.0407992 , -0.03283246],
#        ...,
#        [-0.07850254, -0.14793352,  0.04664878, ..., -0.01558032,
#          0.03511608, -0.03752915],
#        [-0.0903372 , -0.13713319,  0.0645576 , ..., -0.00319759,
#          0.03229715,  0.00725177],
#        [-0.07020202, -0.1068564 ,  0.05326516, ..., -0.00681055,
#         -0.01954372,  0.02036706]])

# %%
reduced_data.shape
# Out:
# (47837, 50)

# %%
df_reduced = pd.DataFrame(reduced_data, columns=[f'PC{i+1}' for i in range(reduced_data.shape[1])])

# %%
df_reduced
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -0.009161  0.001061 -0.013650 -0.039157 -0.027463  0.004440  0.004752
# 1     -0.018490  0.021347 -0.051156 -0.050898 -0.035130  0.021148 -0.002179
# 2     -0.024527 -0.017345 -0.026596 -0.055548 -0.015891  0.022059 -0.028053
# 3     -0.010441 -0.014520 -0.002184 -0.057624 -0.074366 -0.012638 -0.016751
# 4     -0.007400  0.023046 -0.013254 -0.047914 -0.030998  0.001873 -0.004793
# ...         ...       ...       ...       ...       ...       ...       ...
# 47832 -0.086652 -0.086229  0.095960  0.097027 -0.034675 -0.052026  0.062908
# 47833 -0.151780 -0.241421  0.142529  0.118897 -0.015284 -0.015317 -0.030586
# 47834 -0.078503 -0.147934  0.046649  0.036664  0.000719 -0.003878  0.002281
# 47835 -0.090337 -0.137133  0.064558  0.032160 -0.022864 -0.006357 -0.008416
# 3 -0.015058 -0.107458  0.120309  ... -0.015356 -0.017364  0.005492  0.058843
# 4  0.021477  0.001913 -0.032541  ...  0.000774 -0.018658 -0.010231 -0.019157
#
#        PC46      PC47      PC48      PC49      PC50    Topic_Group
# 0  0.023538  0.005641  0.009976  0.045530  0.018438       Hardware
# 1  0.018319 -0.004992 -0.017312 -0.023168  0.006212         Access
# 2  0.053131  0.047940  0.062206 -0.040799 -0.032832       Hardware
# 3 -0.083218  0.018930  0.062140  0.037762  0.033496         Access
# 4  0.008262 -0.019203  0.005562 -0.014634  0.008983  Miscellaneous
#
# [5 rows x 51 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47837 entries, 0 to 47836
# Data columns (total 51 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PC1          47837 non-null  float64
#  1   PC2          47837 non-null  float64
#  2   PC3          47837 non-null  float64
#  3   PC4          47837 non-null  float64
#  4   PC5          47837 non-null  float64
#  5   PC6          47837 non-null  float64
#  6   PC7          47837 non-null  float64
#  7   PC8          47837 non-null  float64
#  8   PC9          47837 non-null  float64
#  9   PC10         47837 non-null  float64
#  10  PC11         47837 non-null  float64
#  11  PC12         47837 non-null  float64
#  12  PC13         47837 non-null  float64
#  13  PC14         47837 non-null  float64
#  14  PC15         47837 non-null  float64
#  15  PC16         47837 non-null  float64
#  16  PC17         47837 non-null  float64
#  17  PC18         47837 non-null  float64
#  18  PC19         47837 non-null  float64
#  19  PC20         47837 non-null  float64
#  20  PC21         47837 non-null  float64
#  21  PC22         47837 non-null  float64
#  22  PC23         47837 non-null  float64
#  23  PC24         47837 non-null  float64
#  24  PC25         47837 non-null  float64
#  25  PC26         47837 non-null  float64
#  26  PC27         47837 non-null  float64
#  27  PC28         47837 non-null  float64
#  28  PC29         47837 non-null  float64
#  29  PC30         47837 non-null  float64
#  30  PC31         47837 non-null  float64
#  31  PC32         47837 non-null  float64
#  32  PC33         47837 non-null  float64
#  33  PC34         47837 non-null  float64
#  34  PC35         47837 non-null  float64
#  35  PC36         47837 non-null  float64
#  36  PC37         47837 non-null  float64
#  37  PC38         47837 non-null  float64
#  38  PC39         47837 non-null  float64
#  39  PC40         47837 non-null  float64
#  40  PC41         47837 non-null  float64
#  41  PC42         47837 non-null  float64
#  42  PC43         47837 non-null  float64
#  43  PC44         47837 non-null  float64
#  44  PC45         47837 non-null  float64
#  45  PC46         47837 non-null  float64
#  46  PC47         47837 non-null  float64
#  47  PC48         47837 non-null  float64
#  48  PC49         47837 non-null  float64
#  49  PC50         47837 non-null  float64
#  50  Topic_Group  47837 non-null  object
# dtypes: float64(50), object(1)
# memory usage: 18.6+ MB

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
encoder.fit(final_df['Topic_Group'])
encoded_labels = encoder.transform(final_df['Topic_Group'])

# %%
final_df['Encoded_Topic_Groups'] = pd.Series(encoded_labels)

# %%
final_df
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     -0.009161  0.001061 -0.013650 -0.039157 -0.027463  0.004440  0.004752
# 1     -0.018490  0.021347 -0.051156 -0.050898 -0.035130  0.021148 -0.002179
# 2     -0.024527 -0.017345 -0.026596 -0.055548 -0.015891  0.022059 -0.028053
# 3     -0.010441 -0.014520 -0.002184 -0.057624 -0.074366 -0.012638 -0.016751
# 4     -0.007400  0.023046 -0.013254 -0.047914 -0.030998  0.001873 -0.004793
# ...         ...       ...       ...       ...       ...       ...       ...
# 47832 -0.086652 -0.086229  0.095960  0.097027 -0.034675 -0.052026  0.062908
# 47833 -0.151780 -0.241421  0.142529  0.118897 -0.015284 -0.015317 -0.030586
# 47834 -0.078503 -0.147934  0.046649  0.036664  0.000719 -0.003878  0.002281
# 47835 -0.090337 -0.137133  0.064558  0.032160 -0.022864 -0.006357 -0.008416
# 47836 -0.070202 -0.106856  0.053265  0.005918 -0.017277  0.059626  0.086372
#
#             PC8       PC9      PC10  ...      PC43      PC44      PC45  \
# 0      0.035211 -0.015146 -0.050542  ...  0.021918  0.027025 -0.049532
# 1      0.040324  0.014768 -0.014623  ... -0.076482  0.031171 -0.026007
# 2      0.080322 -0.011648 -0.026246  ...  0.062659  0.022456 -0.002301
# 3     -0.015058 -0.107458  0.120309  ... -0.017364  0.005492  0.058843
# 4      0.021477  0.001913 -0.032541  ... -0.018658 -0.010231 -0.019157
# ...         ...       ...       ...  ...       ...       ...       ...
# 47832  0.011197  0.068052  0.004082  ...  0.160580 -0.026291 -0.024572
# 47833 -0.104544 -0.059438 -0.113814  ... -0.059684 -0.012487 -0.011955
# 47834  0.106259  0.044839  0.013965  ... -0.009964  0.030096  0.057992
# 47835 -0.045759 -0.044744 -0.066828  ...  0.049761  0.034219  0.051458
# 47836  0.029686  0.036197  0.009025  ...  0.004678  0.005619 -0.008503
#
#            PC46      PC47      PC48      PC49      PC50    Topic_Group  \
# 0      0.023538  0.005641  0.009976  0.045530  0.018438       Hardware
# 1      0.018319 -0.004992 -0.017312 -0.023168  0.006212         Access
# 2      0.053131  0.047940  0.062206 -0.040799 -0.032832       Hardware
# 3     -0.083218  0.018930  0.062140  0.037762  0.033496         Access
# 4      0.008262 -0.019203  0.005562 -0.014634  0.008983  Miscellaneous
# ...         ...       ...       ...       ...       ...            ...
# 47832 -0.053996  0.023311 -0.023581  0.000921 -0.005350         Access
# 47833 -0.031707  0.009093 -0.006207 -0.030114  0.009832  Miscellaneous
# 47834 -0.022950  0.032245 -0.015580  0.035116 -0.037529       Hardware
# 47835 -0.053066 -0.028660 -0.003198  0.032297  0.007252     HR Support
# 47836  0.033911 -0.037588 -0.006811 -0.019544  0.020367       Hardware
#
#        Encoded_Topic_Groups
# 0                         3
# 1                         0
# 2                         3
# 3                         0
# 4                         5
# ...                     ...
# 47832                     0
# 47833                     5
# 47834                     3
# 47835                     2
# 47836                     3
#
# [47837 rows x 52 columns]

# %%
final_df.to_csv('pre_processed_it_ticket_classification_df.csv')
